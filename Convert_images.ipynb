# %%
from setup import *
from image import *
from tqdm import tqdm

# %%
df = pd.read_csv(train_csv); df.head()
# Out:
#                                      Id   Target
# 0  00070df0-bbc3-11e8-b2bc-ac1f6b6435d0     16 0
# 1  000a6c98-bb9b-11e8-b2b9-ac1f6b6435d0  7 1 2 0
# 2  000a9596-bbc4-11e8-b2bc-ac1f6b6435d0        5
# 3  000c99ba-bba4-11e8-b2b9-ac1f6b6435d0        1
# 4  001838f8-bbca-11e8-b2bc-ac1f6b6435d0       18

# %%
out_dir = '/home/fabsta/projects/datascience/competitions/kaggle_human_protein_segmentation/input/train_combined/'
import os
#for i in tqdm(range(10000)):
#for i in tqdm(df.sample(1).iterrows()):
for i,row in df.iterrows():
    curr_id = row['Id']
    red,green,blue = (os.path.join(train,curr_id+'_red.png'),os.path.join(train,curr_id+'_green.png'),os.path.join(train,curr_id+'_blue.png'))
    out_file = os.path.join(out_dir,curr_id+'.png')
    
    cmd = f"convert {red} {green} {blue} -channel RGB -combine {out_file}"
    os.system(cmd)
#os.system('ls')

# %%
test_names = list({f[:36] for f in os.listdir(test)})
test_names[:1]
# Out:
# ['4d36c938-bada-11e8-b2b9-ac1f6b6435d0']

# %%
out_dir = '/home/fabsta/projects/datascience/competitions/kaggle_human_protein_segmentation/input/test_combined/'
import os
#for i in tqdm(range(10000)):
#for i in tqdm(df.sample(1).iterrows()):
for i in tqdm(range(len(test_names))):
    curr_id = test_names[i]
    red,green,blue = (os.path.join(test,curr_id+'_red.png'),os.path.join(test,curr_id+'_green.png'),os.path.join(test,curr_id+'_blue.png'))
    out_file = os.path.join(out_dir,curr_id+'.png')
    #print(f"convert {red} {green} {blue} -channel RGB -combine {out_file}")
    cmd = f"convert {red} {green} {blue} -channel RGB -combine {out_file}"
    os.system(cmd)
# Out:
# 100%|██████████| 11702/11702 [21:05<00:00,  7.88it/s]
